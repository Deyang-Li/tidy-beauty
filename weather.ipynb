# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.2
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
library(skimr)
# Out:
# Attaching package: ‘skimr’
#
# The following object is masked from ‘package:stats’:
#
#     filter

# %%
Africa <- read_csv(file = "Africa.csv")
# Out:
# Parsed with column specification:
# cols(
#   Year = col_double(),
#   Value = col_double()
# )

# %%
Africa$pos = Africa$Value >= 0

# %%
Africa_climate_plot <- Africa %>% 
    filter( Year >= 1950) %>%
    ggplot(aes( 
      x = Year, 
      y = Value,
    fill = pos)) + 
      labs(title = "Time Series of Surface Temperature Anomalies in Africa") +
      scale_x_continuous(breaks=seq(1950, 2020, 10)) +
      scale_y_continuous(breaks=seq(-1, 1.8, 0.2)) +
      geom_bar(stat = "identity",position = "identity", colour = "black", size = 0.05) +
      xlab("Year") +  ylab ("Surface Temperature ( ºC )") +
      theme_light()+
      theme(plot.title = element_text(hjust = 0.5)) +
      scale_fill_manual(values = c("#CCEEFF", "#FFDDDD"), guide = FALSE) 
Africa_climate_plot
# Out:
# plot without title

# %%
ggsave(Africa_wether_plot,filename = "Africa climate plot.pdf",width = 12,height = 9)

# %%
North_America <- read_csv(file = "North America.csv")
# Out:
# Parsed with column specification:
# cols(
#   Year = col_double(),
#   Value = col_double()
# )

# %%
North_America$pos = North_America$Value >= 0

# %%
North_America_climate_plot <- North_America %>% 
    filter( Year >= 1950) %>%
    ggplot(aes( 
      x = Year, 
      y = Value,
    fill = pos)) + 
      labs(title = "Time Series of Surface Temperature Anomalies in North America") +
      scale_x_continuous(breaks=seq(1950, 2020, 10)) +
      scale_y_continuous(breaks=seq(-1, 1.8, 0.2)) +
      geom_bar(stat = "identity",position = "identity", colour = "black", size = 0.05) +
      xlab("Year") +  ylab ("Surface Temperature ( ºC )") +
      theme_light()+
      theme(plot.title = element_text(hjust = 0.5)) +
      scale_fill_manual(values = c("#CCEEFF", "#FFDDDD"), guide = FALSE) 
North_America_climate_plot
# Out:
# plot without title

# %%
ggsave(North_America_climate_plot,filename = "North America climate plot.pdf",width = 12,height = 9)

# %%
South_America <- read_csv(file = "South America.csv")
# Out:
# Parsed with column specification:
# cols(
#   Year = col_double(),
#   Value = col_double()
# )

# %%
# America_weather <- North_America  %>%
#  left_join(South_America, by = "Year") %>%
#  rename(NorthAmerica = Value.x, SouthAmerica = Value.y) %>%
#  mutate(America_temperature = (NorthAmerica + SouthAmerica)/2)

# %%
# America_weather$pos = America_weather$America_temperature >= 0

# %%
South_America$pos = South_America$Value >= 0

# %%
South_America_climate_plot <- South_America %>% 
    filter( Year >= 1950) %>%
    ggplot(aes( 
      x = Year, 
      y = Value,
    fill = pos)) + 
      labs(title = "Time Series of Surface Temperature Anomalies in South America") +
      scale_x_continuous(breaks=seq(1950, 2020, 10)) +
      scale_y_continuous(breaks=seq(-1, 1.8, 0.2)) +
      geom_bar(stat = "identity",position = "identity", colour = "black", size = 0.05) +
      xlab("Year") +  ylab ("Surface Temperature ( ºC )") +
      theme_light()+
      theme(plot.title = element_text(hjust = 0.5)) +
      scale_fill_manual(values = c("#CCEEFF", "#FFDDDD"), guide = FALSE) 
South_America_climate_plot
# Out:
# plot without title

# %%
ggsave(South_America_climate_plot,filename = "South America climate plot.pdf",width = 12,height = 9)

# %%
Europe <- read_csv(file = "Europe.csv")
# Out:
# Parsed with column specification:
# cols(
#   Year = col_double(),
#   Value = col_double()
# )

# %%
Europe$pos = Europe$Value >= 0

# %%
Europe_climate_plot <- Europe %>% 
    filter( Year >= 1950) %>%
    ggplot(aes( 
      x = Year, 
      y = Value,
    fill = pos)) + 
      labs(title = "Time Series of Surface Temperature Anomalies in Europe") +
      scale_x_continuous(breaks=seq(1950, 2020, 10)) +
      scale_y_continuous(breaks=seq(-1, 1.8, 0.2)) +
      geom_bar(stat = "identity",position = "identity", colour = "black", size = 0.05) +
      xlab("Year") +  ylab ("Surface Temperature ( ºC )") +
      theme_light()+
      theme(plot.title = element_text(hjust = 0.5)) +
      scale_fill_manual(values = c("#CCEEFF", "#FFDDDD"), guide = FALSE) 
Europe_climate_plot
# Out:
# plot without title

# %%
ggsave(Europe_climate_plot,filename = "Europe climate plot.pdf",width = 12,height = 9)

# %%
Asia <- read_csv(file = "Asia.csv")
# Out:
# Parsed with column specification:
# cols(
#   Year = col_double(),
#   Value = col_double()
# )

# %%
Asia$pos = Asia$Value >= 0

# %%
Asia_climate_plot <- Asia %>% 
    filter( Year >= 1950) %>%
    ggplot(aes( 
      x = Year, 
      y = Value,
    fill = pos)) + 
      labs(title = "Time Series of Surface Temperature Anomalies in Asia") +
      scale_x_continuous(breaks=seq(1950, 2020, 10)) +
      scale_y_continuous(breaks=seq(-1, 1.8, 0.2)) +
      geom_bar(stat = "identity",position = "identity", colour = "black", size = 0.05) +
      xlab("Year") +  ylab ("Surface Temperature ( ºC )") +
      theme_light()+
      theme(plot.title = element_text(hjust = 0.5)) +
      scale_fill_manual(values = c("#CCEEFF", "#FFDDDD"), guide = FALSE) 
Asia_climate_plot
# Out:
# plot without title

# %%
ggsave(Asia_climate_plot,filename = "Asia climate plot.pdf",width = 12,height = 9)

# %%
Oceania <- read_csv(file = "Oceania.csv")
# Out:
# Parsed with column specification:
# cols(
#   Year = col_double(),
#   Value = col_double()
# )

# %%
Oceania$pos = Oceania$Value >= 0

# %%
Oceania_climate_plot <- Oceania %>% 
    filter( Year >= 1950) %>%
    ggplot(aes( 
      x = Year, 
      y = Value,
    fill = pos)) + 
      labs(title = "Time Series of Surface Temperature Anomalies in Oceania") +
      scale_x_continuous(breaks=seq(1950, 2020, 10)) +
      scale_y_continuous(breaks=seq(-1, 1.8, 0.2)) +
      geom_bar(stat = "identity",position = "identity", colour = "black", size = 0.05) +
      xlab("Year") +  ylab ("Surface Temperature ( ºC )") +
      theme_light()+
      theme(plot.title = element_text(hjust = 0.5)) +
      scale_fill_manual(values = c("#CCEEFF", "#FFDDDD"), guide = FALSE) 
Oceania_climate_plot
# Out:
# plot without title

# %%
ggsave(Oceania_climate_plot,filename = "Oceania climate plot.pdf",width = 12,height = 9)
